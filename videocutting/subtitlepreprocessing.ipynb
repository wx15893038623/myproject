# %%
import pandas as pd

# %%
a = pd.read_csv('line.csv')

# %%
a.set_index(['id'], inplace=True)

# %%
a.head()
# Out:
#                b             e  \
# id
# 1   00:00:25.525  00:00:29.904
# 2   00:00:32.657  00:00:36.119
# 3   00:00:36.286  00:00:39.831
# 4   00:00:39.998  00:00:42.959
# 5   00:00:43.126  00:00:46.087
#
#                                                     x  \
# id
# 1                            <i>This is the Asgardian
# 2                            <i>We are under assault.
# 3   <i>The engines are dead. life support failing....
# 4   <i>Requesting aid from any vessel within range...
# 5         <i>We are 22 jump points out of Asgard.</i>
#
#                                        y
# id
# 1   refugee vessel </i>Statesman<i>.</i>
# 2    I repeat. we are under assault.</i>
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN

# %%
t={}

# %%
for i in a.index:
    if a.y[i]==None:
        t[i]=a.x[i]
    else:
        t[i]=str(a.x[i])+' '+str(a.y[i])

# %%
t
# Out:
# {1: '<i>This is the Asgardian refugee vessel </i>Statesman<i>.</i>',
#  2: '<i>We are under assault. I repeat. we are under assault.</i>',
#  3: '<i>The engines are dead. life support failing.</i> nan',
#  4: '<i>Requesting aid from any vessel within range.</i> nan',
#  5: '<i>We are 22 jump points out of Asgard.</i> nan',
#  6: '<i>Our crew is made up of Asgardian families. We have very few soldiers here.</i>',
#  7: '<i>This is not a warcraft. I repeat. this is not a warcraft.</i>',
#  8: 'Hear me and rejoice. nan',
#  9: 'You have had the privilege of being saved by the Great Titan.',
#  10: 'You may think this is suffering. nan',
#  11: 'No. nan',
#  12: 'It is salvation. nan',
#  13: 'Universal scales tip toward balance because of your sacrifice.',
#  14: 'Smile. nan',
#  15: 'For even in death. you have become Children of Thanos.',
#  16: "I know what it's like to lose. nan",
#  17: "To feel so desperately that you're right...",
#  18: 'yet to fail. nonetheless. nan',
# ...

# %%
a.insert(4,'l',t)

# %%
for i in a.index:
    a['l'][i]=t[i]
# Out:
# C:\Users\1\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\1\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
c = pd.DataFrame(pd.to_datetime(a['e']) - pd.to_datetime(a['b']))

# %%
d= pd.merge(a,c,left_index = True,right_index=True,how='outer')

# %%
d.to_csv('linee.csv')

# %%
data = {'city': ['Beijing', 'Shanghai', 'Guangzhou', 'Shenzhen', 'Hangzhou', 'Chongqing'],
       'year': [2016,2016,2015,2017,2016, 2016],
       'population': [2100, 2300, 1000, 700, 500, 500]}
frame = pd.DataFrame(data, columns = ['year', 'city', 'population', 'debt'])

# %%
frame
# Out:
#    year       city  population debt
# 0  2016    Beijing        2100  NaN
# 1  2016   Shanghai        2300  NaN
# 2  2015  Guangzhou        1000  NaN
# 3  2017   Shenzhen         700  NaN
# 4  2016   Hangzhou         500  NaN
# 5  2016  Chongqing         500  NaN

# %%
# 使用apply函数, 如果city字段包含'ing'关键词，则'判断'这一列赋值为1,否则为0
frame['panduan'] = frame.city.apply(lambda x: 1 if 'ing' in x else 0)

# %%
frame
# Out:
#    year       city  population debt  panduan
# 0  2016    Beijing        2100  NaN        1
# 1  2016   Shanghai        2300  NaN        0
# 2  2015  Guangzhou        1000  NaN        0
# 3  2017   Shenzhen         700  NaN        0
# 4  2016   Hangzhou         500  NaN        0
# 5  2016  Chongqing         500  NaN        1

# %%
print('%s',%b)
# Out:
#   File "<ipython-input-46-f02249cce8ad>", line 1
#     print('%s',%b)
#                ^
# SyntaxError: invalid syntax
